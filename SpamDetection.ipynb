# %% [markdown]
# # **DOWNLOADING DATASETS**

# %%
# !kaggle datasets download -d "uciml/sms-spam-collection-dataset"
# Out:
# Dataset URL: https://www.kaggle.com/datasets/uciml/sms-spam-collection-dataset
# License(s): unknown
# Downloading sms-spam-collection-dataset.zip to /content
#   0% 0.00/211k [00:00<?, ?B/s]
# 100% 211k/211k [00:00<00:00, 74.3MB/s]

# %% [markdown]
# # **EXTRACTING DATASETS**

# %%
# !unzip "/content/sms-spam-collection-dataset.zip"
# Out:
# Archive:  /content/sms-spam-collection-dataset.zip
#   inflating: spam.csv

# %% [markdown]
# # **READING CSV FILE**

# %%
import pandas as pd
df = pd.read_csv("/content/spam.csv", encoding='latin-1')

# %%
df
# Out:
#         v1                                                 v2 Unnamed: 2  \
# 0      ham  Go until jurong point, crazy.. Available only ...        NaN
# 1      ham                      Ok lar... Joking wif u oni...        NaN
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3      ham  U dun say so early hor... U c already then say...        NaN
# 4      ham  Nah I don't think he goes to usf, he lives aro...        NaN
# ...    ...                                                ...        ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...        NaN
# 5568   ham              Will Ì_ b going to esplanade fr home?        NaN
# 5569   ham  Pity, * was in mood for that. So...any other s...        NaN
# 5570   ham  The guy did some bitching but I acted like i'd...        NaN
# 5571   ham                         Rofl. Its true to its name        NaN
#
#      Unnamed: 3 Unnamed: 4
# 0           NaN        NaN
# 1           NaN        NaN
# 2           NaN        NaN
# 3           NaN        NaN
# 4           NaN        NaN
# ...         ...        ...
# 5567        NaN        NaN
# 5568        NaN        NaN
# 5569        NaN        NaN
# 5570        NaN        NaN
# 5571        NaN        NaN
#
# [5572 rows x 5 columns]

# %%
### PREPROCESSING AND CLEANING THE DATASET

# %% [markdown]
# # **Drop the null columns , not used columns**

# %%
df.dropna(axis=1, inplace=True)

# %%
df
# Out:
#         v1                                                 v2
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...
# ...    ...                                                ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...
# 5568   ham              Will Ì_ b going to esplanade fr home?
# 5569   ham  Pity, * was in mood for that. So...any other s...
# 5570   ham  The guy did some bitching but I acted like i'd...
# 5571   ham                         Rofl. Its true to its name
#
# [5572 rows x 2 columns]

# %% [markdown]
# # **Renaming column names**

# %%
df.rename(columns={"v1":"target", "v2":"text"}, inplace=True)

# %%
df
# Out:
#      target                                               text
# 0       ham  Go until jurong point, crazy.. Available only ...
# 1       ham                      Ok lar... Joking wif u oni...
# 2      spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3       ham  U dun say so early hor... U c already then say...
# 4       ham  Nah I don't think he goes to usf, he lives aro...
# ...     ...                                                ...
# 5567   spam  This is the 2nd time we have tried 2 contact u...
# 5568    ham              Will Ì_ b going to esplanade fr home?
# 5569    ham  Pity, * was in mood for that. So...any other s...
# 5570    ham  The guy did some bitching but I acted like i'd...
# 5571    ham                         Rofl. Its true to its name
#
# [5572 rows x 2 columns]

# %% [markdown]
# # **Checking for null values**

# %%
df.isna().any()
# Out:
# target    False
# text      False
# dtype: bool

# %% [markdown]
# # **Using labelencoder for transforming target string objects into numerical values**

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
le.fit(df.target)
# Out:
# LabelEncoder()

# %%
df.target = le.transform(df.target)

# %%
df
# Out:
#       target                                               text
# 0          0  Go until jurong point, crazy.. Available only ...
# 1          0                      Ok lar... Joking wif u oni...
# 2          1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3          0  U dun say so early hor... U c already then say...
# 4          0  Nah I don't think he goes to usf, he lives aro...
# ...      ...                                                ...
# 5567       1  This is the 2nd time we have tried 2 contact u...
# 5568       0              Will Ì_ b going to esplanade fr home?
# 5569       0  Pity, * was in mood for that. So...any other s...
# 5570       0  The guy did some bitching but I acted like i'd...
# 5571       0                         Rofl. Its true to its name
#
# [5572 rows x 2 columns]

# %%
le.classes_
# Out:
# array(['ham', 'spam'], dtype=object)

# %%
df.isna().any()
# Out:
# target    False
# text      False
# dtype: bool

# %% [markdown]
# # **Since text int the fromat of string object , using nlp for understanding the messages and transforming into vector formats**

# %%
df['text'][2]
# Out:
# "Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive entry question(std txt rate)T&C's apply 08452810075over18's"

# %%
import nltk

# %%
# !pip install nltk
nltk.download('punkt_tab')
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.11/dist-packages (3.9.1)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk) (8.1.8)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.11/dist-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from nltk) (4.67.1)
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
#tokenizing the texts

from nltk.tokenize import word_tokenize
df['text'] = df['text'].apply(word_tokenize)

# %%
df
# Out:
#       target                                               text
# 0          0  [Go, until, jurong, point, ,, crazy, .., Avail...
# 1          0           [Ok, lar, ..., Joking, wif, u, oni, ...]
# 2          1  [Free, entry, in, 2, a, wkly, comp, to, win, F...
# 3          0  [U, dun, say, so, early, hor, ..., U, c, alrea...
# 4          0  [Nah, I, do, n't, think, he, goes, to, usf, ,,...
# ...      ...                                                ...
# 5567       1  [This, is, the, 2nd, time, we, have, tried, 2,...
# 5568       0   [Will, Ì_, b, going, to, esplanade, fr, home, ?]
# 5569       0  [Pity, ,, *, was, in, mood, for, that, ., So, ...
# 5570       0  [The, guy, did, some, bitching, but, I, acted,...
# 5571       0                [Rofl, ., Its, true, to, its, name]
#
# [5572 rows x 2 columns]

# %%
df['text'][2]
# Out:
# ['Free',
#  'entry',
#  'in',
#  '2',
#  'a',
#  'wkly',
#  'comp',
#  'to',
#  'win',
#  'FA',
#  'Cup',
#  'final',
#  'tkts',
#  '21st',
#  'May',
#  '2005',
#  '.',
#  'Text',
#  'FA',
#  'to',
#  '87121',
#  'to',
#  'receive',
#  'entry',
#  'question',
#  '(',
#  'std',
#  'txt',
#  'rate',
#  ')',
#  'T',
#  '&',
#  'C',
#  "'s",
#  'apply',
#  '08452810075over18',
#  "'s"]

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
from nltk.stem import SnowballStemmer
from nltk.corpus import stopwords
stemmer = SnowballStemmer("english")
stop_words = set(stopwords.words('english'))
def stem_text(text):

    # Remove stopwords and apply stemming
    return [stemmer.stem(word) for word in text if word.lower() not in stop_words]
   # Join the stemmed words back into a sentence

# Step 5: Apply stemming and stopword removal to the dataset
df['text'] = df['text'].apply(stem_text)


'''from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()

def lemmatize_text(text):
  """Lemmatizes each word in a list of tokens.
  """
  return [lemmatizer.lemmatize(word) for word in text]

df['text'] = df['text'].apply(lemmatize_text)'''
# Out:
# 'from nltk.stem import WordNetLemmatizer\n\nlemmatizer = WordNetLemmatizer()\n\ndef lemmatize_text(text):\n  """Lemmatizes each word in a list of tokens.\n  """\n  return [lemmatizer.lemmatize(word) for word in text]\n\ndf[\'text\'] = df[\'text\'].apply(lemmatize_text)'

# %%
df
# Out:
#       target                                               text
# 0          0  [go, jurong, point, ,, crazi, .., avail, bugi,...
# 1          0             [ok, lar, ..., joke, wif, u, oni, ...]
# 2          1  [free, entri, 2, wkli, comp, win, fa, cup, fin...
# 3          0  [u, dun, say, earli, hor, ..., u, c, alreadi, ...
# 4          0  [nah, n't, think, goe, usf, ,, live, around, t...
# ...      ...                                                ...
# 5567       1  [2nd, time, tri, 2, contact, u., u, å£750, pou...
# 5568       0                 [ì_, b, go, esplanad, fr, home, ?]
# 5569       0             [piti, ,, *, mood, ., ..., suggest, ?]
# 5570       0  [guy, bitch, act, like, 'd, interest, buy, som...
# 5571       0                              [rofl, ., true, name]
#
# [5572 rows x 2 columns]

# %%
'''import gensim
from gensim.models import Word2Vec'''

# %%
df
# Out:
#       target                                               text
# 0          0  [go, jurong, point, ,, crazi, .., avail, bugi,...
# 1          0             [ok, lar, ..., joke, wif, u, oni, ...]
# 2          1  [free, entri, 2, wkli, comp, win, fa, cup, fin...
# 3          0  [u, dun, say, earli, hor, ..., u, c, alreadi, ...
# 4          0  [nah, n't, think, goe, usf, ,, live, around, t...
# ...      ...                                                ...
# 5567       1  [2nd, time, tri, 2, contact, u., u, å£750, pou...
# 5568       0                 [ì_, b, go, esplanad, fr, home, ?]
# 5569       0             [piti, ,, *, mood, ., ..., suggest, ?]
# 5570       0  [guy, bitch, act, like, 'd, interest, buy, som...
# 5571       0                              [rofl, ., true, name]
#
# [5572 rows x 2 columns]

# %%
'''import pandas as pd
from gensim.models import Word2Vec



# Train Word2Vec model
word2vec_model = Word2Vec(sentences=df['text'], vector_size=500, window=5, min_count=1)

# Function to generate sentence embeddings (average of word vectors)
def get_sentence_embedding(sentence, model):
    vectors = [model.wv[word] for word in sentence if word in model.wv]
    if vectors:  # Check if the sentence contains words in the Word2Vec vocabulary
        return sum(vectors) / len(vectors)  # Average of word vectors
    else:
        return [0] * model.vector_size  # Return zero vector if no words in vocabulary

# Apply the function to the 'text' column
df['sentence_embedding'] = df['text'].apply(lambda x: get_sentence_embedding(x, word2vec_model))

# Check the result
print(df[['target', 'sentence_embedding']])'''
# Out:
#       target                                 sentence_embedding
# 0          0  [0.14661013, 0.22315003, 0.23790945, 0.2500203...
# 1          0  [0.15416342, 0.23217803, 0.25472036, 0.2916861...
# 2          1  [0.16036883, 0.2568386, 0.2492064, 0.22946227,...
# 3          0  [0.19987339, 0.3012363, 0.33002788, 0.3599376,...
# 4          0  [0.17128257, 0.2587591, 0.32503897, 0.35387123...
# ...      ...                                                ...
# 5567       1  [0.19549264, 0.30328315, 0.32095817, 0.3188045...
# 5568       0  [0.1583334, 0.2381819, 0.27524248, 0.2894657, ...
# 5569       0  [0.22152296, 0.35037568, 0.351419, 0.40101498,...
# 5570       0  [0.18209597, 0.2757654, 0.31861553, 0.33101583...
# 5571       0  [0.17847538, 0.27770898, 0.30890206, 0.3111588...
#
# [5572 rows x 2 columns]

# %%
df
# Out:
#       target                                               text
# 0          0  [go, jurong, point, ,, crazi, .., avail, bugi,...
# 1          0             [ok, lar, ..., joke, wif, u, oni, ...]
# 2          1  [free, entri, 2, wkli, comp, win, fa, cup, fin...
# 3          0  [u, dun, say, earli, hor, ..., u, c, alreadi, ...
# 4          0  [nah, n't, think, goe, usf, ,, live, around, t...
# ...      ...                                                ...
# 5567       1  [2nd, time, tri, 2, contact, u., u, å£750, pou...
# 5568       0                 [ì_, b, go, esplanad, fr, home, ?]
# 5569       0             [piti, ,, *, mood, ., ..., suggest, ?]
# 5570       0  [guy, bitch, act, like, 'd, interest, buy, som...
# 5571       0                              [rofl, ., true, name]
#
# [5572 rows x 2 columns]

# %% [markdown]
# #**Creating model for spam classification**

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression(class_weight='balanced')

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df['text'].tolist(), df['target'], test_size=0.2, random_state=42)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer()
X_train_str = [' '.join(tokens) for tokens in X_train]
X_test_str = [' '.join(tokens) for tokens in X_test]
X_train = vectorizer.fit_transform(X_train_str)
X_test = vectorizer.transform(X_test_str)

# %%
X_train_str
# Out:
# ["'m boat . still mom . check yo . 'm half nake .",
#  '( bank granit issu strong-buy ) explos pick member * * * * * 300 % * * * * * * * * * * * nasdaq symbol cdgt $ 5.00 per ..',
#  'r give second chanc rahul dengra .',
#  'play smash bros & lt ; # & gt ; religi .',
#  'privat ! 2003 account statement 07973788240 show 800 un-redeem s. i. m. point . call 08715203649 identifi code : 40533 expir 31/10/04',
#  'g say never answer text , confirm/deni',
#  '88066 88066 lost 3pound help',
#  'okey dokey , i\x89û÷ll bit sort stuff .',
#  'come peopl',
#  'wah lucki man ... save money ... hee ...',
#  'much better thank lol',
#  'madam , regret disturbance.might receiv refer check dlf premarica.kind informed.rgd , rakhesh , kerala .',
#  "'m come home 4 dinner .",
#  'ok ...',
#  'ì_ decid faster cos sis go home liao ..',
#  'hi mate rv u hav nice hol messag 3 say hello coz havenåõt sent u 1 age start drive stay road ! rvx',
#  'amaz : rearrang letter give mean ... dormitori = dirti room astronom = moon starer eye = see elect result = lie let recount mother-in-law = woman hitler eleven plus two =twelv plus one amaz ... ! : - )',
#  'good morn plz call sir',
#  'k actual guy meet sunoco howard ? right way',
#  "new theori : argument win situat , lose person . dont argu ur friend .. . . . kick & amp ; say , 'm alway correct . !",
#  'oh yeah ! diet flew window',
#  'watch cartoon , listen music & amp ; eve go templ & amp ; church .. u ?',
#  'india win level seri mean record : )',
#  'armand say get ass epsilon',
#  'tell said eat shit .',
#  'oh , phone phone disconnect',
#  'pleas call custom servic repres freephon 0808 145 4742 9am-11pm guarante å£1000 cash å£5000 prize !',
#  "hey sweet , wonder moment might come ? want send file someon wo n't go yahoo connect suck , rememb set page go download format disc ? could tell ? know way download big file ? download stuff direct internet . help would great , prey ... * teas kiss *",
#  'puriti friendship two smile read forward messag .. smile see name . gud evng',
#  'heard u4 . call night knicker . make beg like u last time 01223585236 xx luv nikiyu4.net',
#  'place man',
#  'welp appar retir',
#  'haha money leh ... later got go tuition ... haha look empti slot drive lesson',
#  'aiyar hard 2 type . u later free tell call n scold n tell u .',
#  "k ll call 'm close",
#  'wat late still earli mah . juz go 4 dinner lor . aiya dunno ...',
#  "yup 's paragon ... havent decid whether 2 cut yet ... hee ...",
#  'watch tv . got new job : )',
#  'privat ! 2004 account statement 07742676969 show 786 unredeem bonus point . claim call 08719180248 identifi code : 45239 expir',
#  'great ! run ttyl !',
#  'hello , love ! goe day ? wish well fine babe hope find job prospect . miss , boytoy ... * teas kiss *',
#  'zoe hit 2 im fuck shitin il defo tri hardest 2 cum 2morow luv u million lekdog',
#  'text way cup stop work . bus',
#  'congratul ore mo owo wa . enjoy wish mani happi moment fro wherev go',
#  'good morn , im suffer fever dysentri .. abl come offic today .',
#  'tell pa. pain de .',
#  'got . seventeen pound seven hundr ml \x89ûò hope ok .',
#  'know complain num .. bettr direct go bsnl offc nd appli ..',
#  'kate jackson rec center 7ish , right ?',
#  'k .. k. : ) congratul ..',
#  'whatsup . dont u want sleep',
#  '88066 lost å£12 help',
#  'japanes proverb : one , u , none , u must indian version : one , let .. none , leav ! ! final kerala version : one , stop .. none , make strike ...',
#  'search 4 happi 1 main sourc unhappi ! accept life way come ! u find happi everi moment u live .',
#  'ok ...',
#  'faith make thing possibl , hope make thing work , love make thing beauti , may three christma ! merri christma !',
#  'ok ... c ya ...',
#  "'m class . holla later",
#  'buy space invad 4 chanc 2 win orig arcad game consol . press 0 game arcad ( std wap charg ) see o2.co.uk/gam 4 term + set . purchas',
#  'hous water dock , boat roll newscast dabbl jazz flute behind wheel',
#  'oh babi hous . come dont new pictur facebook',
#  'thx . well month',
#  'gud mrng dear nice day',
#  'yar want 2 scold u yest late alreadi ... got zhong se qing ? u ask b4 ask ll go w u lor . n u still act real .',
#  'say slowly. ? god , love & amp ; need , clean heart blood.send ten special peopl & amp ; u c miracl tomorrow , , pls , pls ...',
#  'yes princess ! want catch big strong hand ...',
#  'wait , know wesley town ? bet hella drug !',
#  'problem renew . i.ll right away dont know detail .',
#  "part \\do n't initiate\\ '' n't understand ''",
#  'moon come color dream , star make music sms give warm peac sleep . good night',
#  "? ? stand away ? n't heart ach without ? n't wonder ? n't crave ?",
#  'urgent , import inform o2 user . today lucki day ! 2 find log onto http : //www.urawinner.com fantast surpris await',
#  '2 oz guy kinda flaki one friend interest pick $ & lt ; # & gt ; worth tonight possibl',
#  'wait machan . call free .',
#  "honeybe said : * 'm sweetest world * god laugh & amp ; said : * wait , u havnt met person read msg * moral : even god crack joke ! gm+gn+ge+gn : )",
#  'gas station . go .',
#  'yes amma .... life take lot turn sit tri hold steer ...',
#  'hmm . shall bring bottl wine keep us amus ? joke ! ll still bring bottl . red white ? see tomorrow',
#  'sorri miss babe . late slept . hope enjoy drive lesson , boytoy . miss ... * teas kiss *',
#  'ok ... thanx ... gd nite 2 ì_ ...',
#  '1 polyphon tone 4 ur mob everi week ! txt pt2 87575 . 1st tone free ! get txtin tell ur friend . 150p/tone . 16 repli hl 4info',
#  "noth realli , make sure everybodi 's speed",
#  'wish . hold tight . make see import . much mean ... much need ... life ...',
#  'lol would mom would fit tell whole famili crazi terribl',
#  'good , ll find way',
#  'iåõm cool ta luv v.tire 2 caus doin load plan wk , got social servic inspect nurseri ! take care & spk sn x .',
#  'sorri light turn green , meant anoth friend want & lt ; # & gt ; worth may around',
#  'que pase un buen tiempo someth like',
#  'watch telugu movi .. wat abt u ?',
#  'mm ask come enough : - )',
#  'winner ! ! valu network custom select receivea å£900 prize reward ! claim call 09061701461 . claim code kl341 . valid 12 hour .',
#  'yar lor ... keep rain non stop ... u wan 2 go elsewher ?',
#  'otherwis part time job na-tuit ..',
#  'good word .... word may leav u dismay mani time .',
#  'oooh bed ridden ey ? think ?',
#  '4 oclock mine . bash flat plan .',
#  "gsoh ? good spam ladi ? u could b male gigolo ? 2 join uk 's fastest grow men club repli oncal . mjzgroup . 08714342399.2stop repli stop . msg @ å£1.50rcvd",
#  'gram usual run like & lt ; # & gt ; , half eighth smarter though get almost whole second gram & lt ; # & gt ;',
#  'im good ! think ...',
#  'one day crab run sea shore .. wave came n clear footprint crab .. crab ask : frnd r u clear beauti footprint ? wave repli : fox follow ur footprint catch ! that clear : ) frndsship never let u dwn : - ) gud nyt ..',
#  'dunno jus say go lido . time 930 .',
#  "free msg : get gnarl barkley \\crazy\\ '' rington total free repli go messag right ! ''",
#  'alway say welp ?',
#  'get offici england poli rington colour flag yer mobil tonight game ! text tone flag 84199 . optout txt eng stop box39822 w111wx å£1.50',
#  'gud mrng dear hav nice day',
#  "also thk fast ... xy suggest one . u dun wan 's ok . go 2 rain leh got gd .",
#  'fran decid 2 go n e way im complet broke knacker got bout 3 c u 2mrw love janx p.s dad fone , -no credit',
#  'messag free . welcom new & improv sex & dog club ! unsubscrib servic repli stop . msgs @ 150p 18',
#  'free 1st week ! no1 nokia tone 4 ur mobil everi week txt nokia 8077 get txting tell ur mate . www.getzed.co.uk pobox 36504 w45wq 16+ norm150p/ton',
#  'cool . like swim ? pool jacuzzi hous .',
#  "cours . guess god 's got hold right .",
#  'oh get even u .... u ?',
#  'whos class : - )',
#  'loosu go hospit . de dont let careless .',
#  'k , roommat also want dubsack anoth friend may also want plan bring extra , ll tell know sure',
#  'oh ... haha ... den shld went today ... gee , nvm la ... kaiez , dun mind goin jazz oso ... scare hiphop open cant catch ...',
#  "'m happi babe ! woo hoo parti dude !",
#  'allo ! brave buse taken train triumph . mean we\x89û÷r b\x89û÷ham . jolli good rest week',
#  'tell need investig anywher .',
#  'urgent ! pleas call 0906346330 . abta complimentari 4 * spanish holiday å£10,000 cash await collect sae & cs box 47 po19 2ez 150ppm 18+',
#  'call ok said call',
#  'urgent ! mobil . award å£2000 bonus caller prize 5/9/03 final tri contact u ! call landlin 09064019788 box42wr29c , 150ppm',
#  'miss call miss call khelat kintu opponent miss call dhort lage . that rule . one great phone receiv qualiti win .',
#  'wife.how knew time murder exact',
#  'u lunch alon ? bore ...',
#  'true lov n care wil nevr go unrecogn . though somon often make mistak valu . definit undrstnd start miss .',
#  'thought king hill thing .',
#  'thk ì_ got ta go home urself . cos ll b go shop 4 fren present .',
#  'studi . i.ll free next weekend .',
#  'love ya tri budget money better babe . gari would freak knew',
#  'ok ...',
#  "genius 's . brother . pls send number skype .",
#  "want 2 get laid tonight ? want real dog locat sent direct 2 ur mob ? join uk 's largest dog network bt txting gravel 69888 ! nt . ec2a . 31p.msg @ 150p",
#  "wish famili merri \\x\\ '' mas happi new year advanc .. ''",
#  'fujitsu seri lifebook good ?',
#  'friendship poem : dear dear u r near hear dont get fear live cheer tear u r alway dear . gud ni8',
#  'haha yeah , 2 oz kind shitload',
#  "make girl happi ? 's difficult make girl happi . u need ... 1 . friend 2 . companion 3 . lover 4 . chef . . . & lt ; # & gt ; . good listen & lt ; # & gt ; . organ & lt ; # & gt ; . good boyfriend & lt ; # & gt ; . clean & lt ; # & gt ; . sympathet & lt ; # & gt ; . athlet & lt ; # & gt ; . warm . . . & lt ; # & gt ; . courag & lt ; # & gt ; . determin & lt ; # & gt ; . true & lt ; # & gt ; . depend & lt ; # & gt ; . intellig . . . & lt ; # & gt ; . psychologist & lt ; # & gt ; . pest extermin & lt ; # & gt ; . psychiatrist & lt ; # & gt ; . healer . . & lt ; # & gt ; . stylist & lt ; # & gt ; . driver . . aaniy pudunga venaam ..",
#  'arun u transfr amt',
#  "prabha .. 'm soryda .. reali .. frm heart 'm sori",
#  'part check iq',
#  'noth spl .. wat abt u whr ru ?',
#  "yeah 's quit bit left , ll swing tomorrow get",
#  'look like found someth smoke , great job !',
#  'babe , got enough money pick bread milk ? ll give back get home ?',
#  'askd u question hour . answer',
#  'today voda number end 7548 select receiv $ 350 award . match pleas call 08712300220 quot claim code 4041 standard rate app',
#  'dont pick call someth import tell . hrishi',
#  'text banneduk 89555 see ! cost 150p textoper g696ga 18+ xxx',
#  'miss too.pray inshah allah',
#  'hello peach ! cake tast lush !',
#  "guessin ai n't gon na 9 ?",
#  'anyway , go gym whatev , love * smile * hope ok good day babe ... miss much alreadi',
#  'probabl , still go stuff',
#  'got call landlin number . . . ask come anna nagar . . . go afternoon',
#  'dude ive see lotta corvett late',
#  "\\the world suffer lot ... violenc bad peopl . silenc good peopl ! \\ ''",
#  'dear dave final notic collect 4 * tenerif holiday # 5000 cash award ! call 09061743806 landlin . tcs sae box326 cw25wx 150ppm',
#  'come back tampa ffffuuuuuuu',
#  '! want pleas insid outsid bedroom ...',
#  'hey pple ... $ 700 $ 900 5 night ... excel locat wif breakfast hamper ! ! !',
#  'oh ? send address',
#  "sorri cant take call right . happen r 2waxsto wat want . come ill get medic insur . ll abl deliv basic care . 'm current shop right medic insur . give til friday morn . that i.ll see major person guid right insur .",
#  "u wake alreadi ? wat u ? u pick us later rite ? 'm take sq825 , reach ard 7 smth 8 like dat . u check e arriv time . c ya soon ...",
#  'farm open ?',
#  'speak cash yet ?',
#  "n't make life stressful .. alway find time laugh .. may add year life ! sure add life ur year ! ! gud ni8 .. swt dream ..",
#  'lmao ok wont need u hair anymor .',
#  'uncl atlanta . wish guy great semest .',
#  'ultim tor motiv tui achiev kor .',
#  '\\can pleas come imin town.dontmatt urgoin outl8r',
#  'moment day , value-morn bring hope , afternoon bring faith , even bring luv , night bring rest , wish u find today.good morn',
#  'decemb ! mobil 11mths+ ? entitl updat latest colour camera mobil free ! call mobil updat co free 08002986906',
#  'email yifeng part oredi .. ì_ get fr ..',
#  'object . bf come .',
#  "come home . n't want u miser",
#  'congrat ! 2 mobil 3g videophon r . call 09061744553 ! videochat wid ur mate , play java game , dload polyh music , nolin rentl . bx420 . ip4 . 5we . 150pm',
#  "born , god said , \\oh ! anoth idiot\\ '' . born",
#  "n't , prize go anoth custom . & c www.t-c.biz 18+ 150p/min polo ltd suit 373 london w1j 6hl pleas call back busi",
#  'wen ur lovabl bcum angri wid u , dnt take serious .. coz angri childish n true way show deep affect , care n luv ! .. kettoda manda ... nice day da .',
#  "yeah . got list u joanna 'm feel realli anti social",
#  'see , re christmassi !',
#  'k ll head min , see',
#  "t-mobil custom may claim free camera phone upgrad & pay & go sim card loyalti . call 0845 021 3680.offer end 28thfeb.t & c 's appli",
#  'guess useless call u 4 someth import .',
#  'hey sexi bun ! day ? word morn ym ... : - ( ... think',
#  'cant pick phone right . pls send messag',
#  "hear new \\divorc barbie\\ '' ? come ken 's stuff ! ''",
#  'thank look . realli appreci .',
#  'go join tomorrow .',
#  'good luck ! draw take place 28th feb 06 . good luck ! remov send stop 87239 custom servic 08708034412',
#  'say hi get ass back south tampa ( prefer kegger )',
#  "wine flow 'm never ..",
#  'cant think anyon * spare room * top head',
#  'hot live fantasi call 08707509020 20p per min ntt ltd , po box 1327 croydon cr9 5wb 0870 nation rate call',
#  'happen yo date ?',
#  'u secret admir . reveal think u r special . call 09065174042 . opt repli reveal stop . 1.50 per msg recd . cust care 07821230901',
#  'happen tell truth',
#  'noth , got msg frm tht unknown ..',
#  "could seen .. did't recognis face . : )",
#  'sms . ac jsco : energi high , u may know 2channel . 2day ur leadership skill r strong . psychic ? repli an w/question . end ? repli end jsco',
#  'say somebodi name tampa',
#  'yo there class tmrw right ?',
#  'urgent ! mobil number award å£2000 prize guarante . call 09061790121 land line . claim 3030 . valid 12hrs 150ppm',
#  'yes . fine . love . safe .',
#  'keep payasam rinu bring',
#  'need . person give na .',
#  'aiyah u ok alreadi lar . e nydc wheellock ?',
#  '. 1 nokia tone 4 ur mob everi week ! txt nok 87021 . 1st tone free ! get txtin tell ur friend . 150p/tone . 16 repli hl 4info',
#  'campus . librari ?',
#  'enjoy shower possess pour u ur love one , bcoz world lie , golden gift love truli ..',
#  'sur ill give : - ) come review .',
#  'lord ring : return king store ! repli lotr 2 june 4 chanc 2 win lotr soundtrack cds stdtxtrate . repli stop end txts',
#  "pls send comprehens mail 'm pay , much .",
#  'current lead bid 151 . paus auction send . custom care : 08718726270',
#  'wake 4 afternoon , sup',
#  'let know ve got money carlo make call',
#  'contact date servic someon know ! find , call mobil landlin 09064017305 pobox75ldns7',
#  'k : ) give kvb acc detail : )',
#  'ok. mani buy .',
#  'call .. messag .. miss call',
#  "yo , 'm parent ' gettin cash . good news : pick downstem",
#  'dear subscrib ur draw 4 å£100 gift voucher b enter receipt correct an . elvi presley birthday ? txt answer 80062',
#  'took tablet . reaction morn .',
#  'sister got place birla soft da : - )',
#  "keep see weird shit bein \\woah\\ '' realis 's actual reason 'm \\ '' oh\\ '' ''",
#  'pls pls send mail know relat come deliv ? know cost , risk , benefit anyth els . thank .',
#  'use foreign stamp countri . good lectur .',
#  'mom want know',
#  'earli bird ! purchas yet ?',
#  'bring got',
#  'oki ...',
#  'hiya , good day ? spoken sinc weekend ?',
#  'japanes proverb : one , u , none , u must indian version : one , let .. none , leav ! ! final kerala version : one , stop .. none , make strike ...',
#  'oh yeah , hav great time newquay-send postcard ! 1 look girl im gone ( u know 1im talkin bout ! ) xx',
#  'tri someth dear . read someth exam',
#  'k , make sens , btw carlo difficult guy gon na smoke go pick second batch get gas',
#  '? ? ? ? hello wat talk email address ?',
#  "'m reach home 5 min .",
#  'though shd go n fun bar town someth \x89ûò sound ok ?',
#  "'m okay . chase dream . 's good . next .",
#  'sorri im stil fuck last nite went tobe 430 got 4 work 630',
#  "well n't avail washob nob last night ask nickey platt instead ! ;",
#  'ello babe u ok ?',
#  'life spend someon lifetim may meaningless moment spent someon realli love mean life ..',
#  'wake sinc . check stuff saw true avail space . pls call embassi send mail .',
#  "'m home . doc gave pain med say everyth fine .",
#  'u sleep .. go take ? haha .. got spys wat .. onlin check n repli mail lor ..',
#  "loan purpos å£500 - å£75,000 . homeown + tenant welcom . previous refus ? still help . call free 0800 1956669 text back help '",
#  'yeah , give call ve got minut',
#  'lover ? need ...',
#  "know . 's anthoni . bring money . ve school fee pay rent stuff like . that need help . friend need .... |",
#  'hope would send messag . rent due dont enough . reserv complet gone . loan need hope could . balanc & lt ; # & gt ; . way could get , till mid march hope pay back .',
#  "pleas n't text anymor . noth els say .",
#  'supervisor find 4 one lor thk student . havent ask yet . tell u aft ask .',
#  'goodmorn , today late & lt ; decim & gt ; min .',
#  'hi . hope good day . better night .',
#  'think one say clear . ok leav need ask . go come',
#  'hmm well , night night',
#  'ur go 2 bahama ! callfreefon 08081560665 speak live oper claim either bahama cruis ofå£2000 cash 18+on . opt txt x 07786200117',
#  "'s justbeen overa week sinc broke alreadi brain go mush !",
#  'dont thnk wrong call us',
#  '[ \x89û_ ] anyway , mani good even u !',
#  "come around & lt ; decim & gt ; pm vikki .. 'm otsid nw , il come tht time",
#  'update_now - xmas offer ! latest motorola , sonyericsson & nokia & free bluetooth ! doubl min & 1000 txt orang . call mobileupd8 08000839402 call2optout/f4q=',
#  "call later . afternoon onword mtnl servic get problem south mumbai . hear n't listen .",
#  "'m bruce & amp ; fowler 'm mom 's car ca n't park ( long stori )",
#  'still play gautham ?',
#  'messag . food ?',
#  'time want come ?',
#  'k .. give back thank .',
#  'england v macedonia - dont miss goals/team news . txt ur nation team 87077 eg england 87077 tri : wale , scotland 4txt/ì¼1.20 poboxox36504w45wq 16+',
#  'enjoy ur life . . good night',
#  'good even ! ttyl',
#  'take exam march 3',
#  'aiyah ok wat long got improv alreadi wat ...',
#  ': - ) one good partnership go take lead : )',
#  'u get messag',
#  'u call ...',
#  'tell u headach want use 1 hour sick time .',
#  'never tri alon take weight tear come ur heart fall ur eye ... alway rememb stupid friend share ... bslvyl',
#  'raji .. pls favour . pls convey birthday wish nimya . pls . today birthday .',
#  'time . i\x89û÷m prob 3',
#  "\\hi kate love see tonight ill phone tomorrow . got sing guy gave card ! xxx\\ '' ''",
#  'usual .. iam fine , happi & amp ; well .. : )',
#  'nope watch tv home ... go . v bore ...',
#  'ps u ur grown right ?',
#  'k , wat tht incid ?',
#  'u awak ? snow ?',
#  'she. good . wonder wont say hi she. smile . cope long distanc',
#  'intrepid duo ! great time see soon .',
#  'gobi art colleg',
#  'credit top http : //www.bubbletext.com renew pin tgxxrz',
#  '? thought put back box',
#  'wnt buy bmw car urgent .. vri urgent.but hv shortag & lt ; # & gt ; lacs.ther sourc arng dis amt . & lt ; # & gt ; lac .. that prob',
#  'hi , mobil . & lt ; # & gt ; ad contact list www.fullonsms.com great place send free sms peopl visit fullonsms.com',
#  'easi ah ? sen got select mean good ..',
#  "know 'm lack particular dramastorm 's detail part 'm worri",
#  'k.k.how busi ?',
#  "probabl earlier station 's think",
#  'sorri , meet ll call later',
#  '< forward 21870000 > hi - mailbox messag sms alert . 40 match . pleas call back 09056242159 retriev messag match cc100p/min',
#  'got anoth job ! one hospit data analysi someth , start monday ! sure thesi got finish',
#  'free entri gr8prize wkli comp 4 chanc win latest nokia 8800 , psp å£250 cash everi wk.txt great 80878 http//www.gr8prizes.com 08715705022',
#  "call you/carlo is/ar , phone 's vibrat act might hear text",
#  "'m smoke peopl use \\wyli smoke much\\ '' justifi ruin shit ''",
#  'want new video phone750 anytim network min 150 text five pound per week call 08000776320 repli deliveri tomorrow',
#  'sound great ! home ?',
#  'k.then special ?',
#  'number u live ? 11 ?',
#  "\\oh fuck . juswok bed boatin dock . slept wid 25 year old . spinout ! giv u da gossip l8r . xxx\\ '' ''",
#  'knock knock txt whose 80082 enter r week draw 4 å£250 gift voucher 4 store yr choic . & cs www.tkls.com age16 stoptxtstopå£1.50/week',
#  'tessi .. pls favor . pls convey birthday wish nimya .. pls dnt forget . today birthday shija',
#  'dice , art class 6 thru 9 : ( thank though . idea time come tomorrow ?',
#  'u got person stori',
#  'yeah tote . u wan na ?',
#  'sorri da : ) thought call lot time : ) lil busy.i call noon ..',
#  "n't pay attent",
#  'good morn , love ... go sleep wish great day full feel better opportun ... last thought babe , love * kiss *',
#  'u drive lor .',
#  'huh slow tot u reach long ago liao ... u 2 day 4 leh ...',
#  "dun cut short leh . u dun like ah ? fail . 's quit sad .",
#  'shop lor . rain mah hard 2 leav orchard .',
#  'never blame day ur life . good day give u happi . bad day give u experi . essenti life ! god bless ! good morn . :',
#  'ok . april . cant wait',
#  'love ! daddi make scream pleasur ! go slap ass dick !',
#  'yes , reg ciao !',
#  '2nd time tri contact u. u å£1450 prize claim call 09053750005 b4 310303 . & cs/stop sms 08718725756 . 140ppm',
#  'told number gautham ..',
#  'someonon know tri contact via date servic ! find could call mobil landlin 09064015307 box334sk38ch',
#  'got c ... lazi type ... forgot ì_ lect ... saw pouch like v nice ...',
#  "sad stori man - last week b'day . wife did'nt wish . parent forgot n kid . went work . even colleagu wish .",
#  'nice day today . love dear .',
#  'drop tank',
#  'sunshin hol . claim ur med holiday send stamp self address envelop drink us uk , po box 113 , bray , wicklow , eir . quiz start saturday ! unsub stop',
#  'oh k : ) got job what ?',
#  'inde way either - !',
#  'sorri , ll call later ok bye',
#  "hi harish 's rent transfr ur acnt .",
#  'urgent urgent ! 800 free flight europ give away , call b4 10th sept & take friend 4 free . call claim 09050000555 . ba128nnfwfly150ppm',
#  'hide anythi keep distanc',
#  'met stranger choos friend . long world stand , friendship never end . let friend forev ! ! ! gud nitz ...',
#  "welcom uk-mobile-d msg free give free call 08719839835 . futur mgs bill 150p daili . cancel send \\go stop\\ '' 89123 ''",
#  'hank lotsli !',
#  'award sipix digit camera ! call 09061221061 landlin . deliveri within 28day . cs box177 . m221bp . 2yr warranti . 150ppm . 16 . p på£3.99',
#  'hi , wlcome back , wonder got eaten lion someth , noth much',
#  'yup',
#  "lol n't know awesom phone . could click delet right want .",
#  'current food . alon also',
#  'got job wipro : ) get everi thing life 2 3 year .',
#  'gentl princess ! make sweet gentl love ...',
#  'friendship poem : dear dear u r near hear dont get fear live cheer tear u r alway dear . gud ni8',
#  'yay ! better told 5 girl either .',
#  'esplanad lor . els ...',
#  'thank hope good day today',
#  'hmmm.but give one day ..',
#  "text . finish long time ago shower er'yth !",
#  'enjoy watch play footbal basketbal . anyth outdoor . ?',
#  'doubl min txts 4 6month free bluetooth orang . avail soni , nokia motorola phone . call mobileupd8 08000839402 call2optout/n9dx',
#  'good even ! roger . ?',
#  'ok. wahala . rememb friend need ...',
#  'accident brought em home box',
#  'aight , thank comin',
#  'hey tmr mayb meet yck',
#  "'m . lip sync shangela .",
#  'pls need dat slowli vomit .',
#  "'m watch lotr w sis dis aft . u wan 2 meet 4 dinner nite ?",
#  'hi : ) final complet cours : )',
#  'when/wher pick',
#  'yes possibl dint tri . pls dont tell one k',
#  'hey . happen ? u switch ur cell whole day . isnt good . u care , give call tomorrow .',
#  "\\alrit hunni ! wot u 2 2nite ? didnt end goin town jus da pub instead ! jus chillin da mo bedroom ! love jen xxx.\\ '' ''",
#  'wif famili book tour packag .',
#  'darren say dat u meet da ge den dun meet 4 dinner . cos later u leav xy feel awkward . den u meet 4 lunch lor .',
#  "aight sorri take ten year shower . 's plan ?",
#  'ok u tell wat time u come later lor .',
#  'anyth lor .',
#  'back brum ! thank put us keep us happi . see soon',
#  '6time',
#  'happi birthday ... may ur dream come true ...',
#  'wyli updat : weed dealer carlo went freedom class lunsford',
#  'im reali soz imat mum 2nite 2moro',
#  'ya came ago',
#  'awesom , text re restock',
#  'badrith chennai : ) sure pick us : ) competit .',
#  'yup . thk u oso bore wat .',
#  'wat uniform ? get ?',
#  'pls ask macho much budget bb bold 2 cos saw new one & lt ; # & gt ; dollar .',
#  'sorri , ll call later',
#  'anytim ...',
#  'pleas give 2 pick tuesday even 8 ok .',
#  "freemsg : hey - 'm buffi . 25 love satisfi men . home alon feel randi . repli 2 c pix ! qlynnbv help08700621170150p msg send stop stop txts",
#  'even friend priest call',
#  'probabl & lt ; # & gt ; % .',
#  "'m sorri . ve join leagu peopl dont keep touch . mean great deal . friend time even great person cost . great week.|",
#  'gain right wife.dont demand it.i tri husband too.let see',
#  'know ! grumpi old peopl . mom like better lie . alway one play joke ...',
#  'oop , & lt ; # & gt ; ?',
#  'im done . studyn librari',
#  'problem babi . good time talk ? call left messag .',
#  'yo dude guess got arrest day',
#  'ha ... us e thing . got tv 2 watch . u thk 2 go tonight u alreadi haf smth mind ...',
#  'thank ! bomb date phone want say !',
#  "hi elain , today 's meet confirm ?",
#  'k.k .. sister kid ?',
#  'nice talk ! pleas dont forget pix : ) want see ...',
#  "damn , poor zac n't stand chanc",
#  "'s fine , give call know want question",
#  'love aathi .. love u lot ..',
#  'hello , per request & lt ; # & gt ; rs.5 transfer',
#  'derek done class ?',
#  '. thank . ve wonder',
#  "say ll give call friend 's got money 's definit buy end week",
#  "'s signific ?",
#  'urgent ! tri contact . last weekend draw show å£900 prize guarante . call 09061701939 . claim code s89 . valid 12hrs',
#  'well , meant oppos drunken night',
#  'sorri . never hear unless book . one kinda joke -- thet realli look skinni white girl . one line -- much camera . someth like re cast look .',
#  '... pub ?',
#  "n't pattern recent crap weekend ?",
#  'prakesh know .',
#  "said , '' u mind go bedroom minut ? `` '' ok '' , sed sexi mood . came 5 minut latr wid cake ... n wife ,",
#  "bore speed date ? tri speedchat , txt speedchat 80155 , n't like em txt swap get new chatter ! chat80155 pobox36504w45wq 150p/msg rcd 16",
#  'hope get away 7 , langport . still town tonight ?',
#  'great ! offic today ?',
#  'site simul test . give tough question test readi .',
#  'like call mittelschmertz . googl . dont paracetamol dont worri go .',
#  'dunno lei shd b drive lor cos go sch 1 hr oni .',
#  'ah , well confus thing , doesnt ? thought friend . mayb wrong thing alreadi sort invit -tho may come cos money .',
#  "nvm ... 'm go wear sport shoe anyway ... 'm go late leh .",
#  'spend new year brother famili . let plan meet next week . readi spoil ? : )',
#  'escap theatr . . go watch kavalan minut',
#  'could work , ll reach consensus next meet',
#  "'s cool , let know kick around & lt ; # & gt ; , ll day",
#  'wait.i come .. & lt ; # & gt ; min : )',
#  'ok ... ur typic repli ...',
#  "hope thing went well doctor ' ; ) remind still need 2go.did u c littl thing left loung ?",
#  'that cool . like photo . sexi !',
#  'piti , * mood . ... suggest ?',
#  "yet . 'd like keep touch easiest way barcelona . way ru hous ?",
#  'got ! look scrumptious ... daddi want eat night long !',
#  'watch hous \x89ûò entertain \x89ûò get whole hugh lauri thing \x89ûò even stick \x89ûò inde especi stick .',
#  'ill & lt ; # & gt ; ok .',
#  'apart one told yesterday ?',
#  'happen dear . silent . tens',
#  "prabha .. 'm soryda .. reali .. frm heart 'm sori",
#  'hi mom might back later & lt ; # & gt ;',
#  'noe la ... u wana pei bf oso rite ... k lor , day den ...',
#  'tell friend come round til like & lt ; # & gt ; ish ?',
#  "yeah got 2 v apologet . n fallen actin like spoilt child got caught . till 2 ! wo n't go ! bad cheer . ?",
#  'sir , receiv account anoth 1hr time . sorri delay .',
#  'k : ) k.are colleg ?',
#  'next month get upto 50 % call 4 ur standard network charg 2 activ call 9061100010 c wire3.net 1st4term pobox84 m26 3uz cost å£1.50 min mobcudb',
#  'dont gim lip caveboy',
#  'cant pick phone right . pls send messag',
#  "garag key ? n't bookshelf",
#  'swhrt u dey , hope ur ok , tot u 2day.lov n miss.tak care .',
#  "hope know 'm still mad .",
#  '! found diff farm shop buy chees . way back , call ?',
#  "'m gon na rip uterus .",
#  'gon na get rimac access',
#  'somewher beneath pale moon light someon think u dream come true ... goodnit & amp ; sweet dream',
#  'got meh ... ?',
#  'k .. k .. special today ?',
#  'll join & lt ; # & gt ; bus',
#  'ìï say like dat dun buy ericsson oso oredi lar ...',
#  'ask sen come chennai search job .',
#  'k need login anyth',
#  'today voda number end 5226 select receiv ? 350 award . hava match pleas call 08712300220 quot claim code 1131 standard rate app',
#  'hello . need posh bird chap user trial prod champney . put ? need address dob asap . ta r',
#  'sorri , ll call later',
#  'good day too.pray me.remov teeth pain maintain stuff .',
#  'yup ... remb ... think book ...',
#  'u free sat rite ? u wan 2 watch infern affair wif n darren n mayb xy ?',
#  "night worri appt . 's shame miss girl night quizz popcorn hair .",
#  'dad get back .',
#  "boo . 's thing ? 'm back home littl bore alreadi : - (",
#  'rememb day ..',
#  'might come kerala 2 days.so prepar take leav finalis .dont plan travel visit.ne finish urgent work .',
#  'urgent ! call 09066350750 landlin . complimentari 4 * ibiza holiday 10,000 cash await collect sae & cs po box 434 sk3 8wp 150 ppm 18+',
#  'r u sure ll understand ! wine * good idea slurp !',
#  'forgot take 3 year shower , sorri . at/your phone dead yet ?',
#  'midnight earliest',
#  'home alway chat',
#  'might ax well im .',
#  'll get headach tri figur . u trust math . promis . : - )',
#  'u 447801259231 secret admir look 2 make contact u-find r * reveal think ur special-cal 09058094597',
#  "miss call caus yell scrappi . miss u . ca n't wait u come home . 'm lone today .",
#  'think disturb da',
#  'hey check da . list da .',
#  'ill call u 2mrw ninish , address icki american freek wont stop callin 2 bad jen k eh ?',
#  "said , '' u mind go bedroom minut ? `` '' ok '' , sed sexi mood . came 5 minut latr wid cake ... n wife ,",
#  "unfortun ve found pick sister airport even n't think ll go . tri go one th",
#  'natalja ( 25/f ) invit friend . repli yes-440 no-440 see : www.sms.ac/u/nat27081980 stop ? send stop frnd 62468',
#  "hex ' place talk ? explain !",
#  'lift hope offer money . need . especi end month approach hurt studi . anyway gr8 weekend',
#  'time u wrkin ?',
#  'ok. watch tv .',
#  'say hi get ass back south tampa ( prefer kegger )',
#  "n't , prize go anoth custom . & c www.t-c.biz 18+ 150p/min polo ltd suit 373 london w1j 6hl pleas call back busi",
#  'sent . type food like ?',
#  "even * v good somewhat event laden . fill , n't worri \x89û_ head * ok throat * wreck . see six !",
#  "cours ! n't teas ... know simpli must see ! * grin * ... keep post prey ... * love smile * * devour kiss *",
#  'win year suppli cds 4 store ur choic worth å£500 & enter å£100 week draw txt music 87066 ts & cs www.ldew.com.subs16+1win150ppmx3',
#  "re peopl mu , 'm tabl lambda",
#  'congrat ! nokia 3650 video camera phone call 09066382422 call cost 150ppm ave call 3min vari mobil 16+ close 300603 post bcm4284 ldn wc1n3xx',
#  'dear , shall mail tonite.busi street , shall updat tonite.th look ok.varunnathu edukkukaye raksha ollu.but good one real sens .',
#  'around still asleep ? : v',
#  'good afternoon , love ! goe day ? hope mayb got lead job . think , boytoy send passion kiss across sea',
#  'play w comput ? aiyah tok 2 u lor ?',
#  'xmas stori peac .. xmas msg love .. xmas miracl jesus .. hav bless month ahead & amp ; wish u merri xmas ...',
#  "'s point hangin mr right 's makin u happi",
#  'got xmas radio time . get',
#  'show ur colour ! euro 2004 2-4-1 offer ! get england flag & 3lion tone ur phone ! click follow servic messag info !',
#  'east coast',
#  'home lei ...',
#  'thread wishlist section forum ppl post nitro request . start last page collect bottom .',
#  'wan na gym harri',
#  'anyway serious hit re back otherwis light armand alway shit and/or vomit',
#  'come mu , re sort narcot situat',
#  'next amaz xxx picsfree1 video sent enjoy ! one vid enough 2day text back keyword picsfree1 get next video .',
#  'sun ah ... thk mayb dun anythin ... thk book e lesson ... e pilat orchard mrt u noe hor ...',
#  'ok',
#  "n't know u u n't know . send chat 86688 let 's find ! 150p/msg rcvd . hg/suite342/2lands/row/w1j6hl ldn . 18 year .",
#  "'s ì© $ 140 ard ... ìä rest ard $ 180 least ... ì© price 4 ì© 2 bedrm ( $ 900 )",
#  'time ur flight tmr ?',
#  'bishan lei ... tot ì_ say lavend ?',
#  'go dinner.msg .',
#  'yeah , probabl swing roommat finish girl',
#  'haha kid , papa need drug',
#  'yes appt ?',
#  'ok prob . take ur time .',
#  'hi ur lookin 4 sauci daytim fun wiv busti marri woman free next week chat 2 sort time 09099726429 janinexx callså£1/minmobsmorelkpobox177hp51fl',
#  'yup thk r e teacher said make face look longer . darren ask 2 cut short .',
#  'th gower mate ! ? ! r u man ? good wale ill b back åômorrow . c u wk ? msg 4 ? åð random !',
#  'mm ask call radio',
#  'place man',
#  'u lousi , run alreadi come back half dead ... hee ...',
#  'hope enjoy game yesterday . sorri ve touch pls know fond bein thot . great week . abiola',
#  'dnt wnt tlk wid u',
#  'great . never better . day give even reason thank god',
#  "'m solihul , | want anyth ?",
#  'hurri , ve weed-defici like three day',
#  'good afternon , love . today ? hope good mayb interview . wake miss babe . passion kiss across sea',
#  'pick rayan macleran .',
#  'think actual talk ? call boss morn ? went place last year told could go get car fix cheaper . kept tell today much hope would come back , alway regret get number , etc .',
#  'hi kate even ? hope see tomorrow bit bloodi babyjontet ! txt back u . : ) xxx',
#  '! expect whenev text ! hope goe well tomo',
#  'life face choic toss coin becoz settl question coin air u know heart hope . gudni8',
#  'hair cream ship .',
#  'onlin transact ?',
#  'aight plan come later tonight ?',
#  "'m come back thursday . yay . gon na ok get money . cheer . oh yeah . everyth alright . how school . call work",
#  'congrat kano .. whr treat maga ?',
#  'say slowly. ? god , love & amp ; need , clean heart blood.send ten special peopl & amp ; u c miracl tomorrow , , pls , pls ...',
#  'gorgeous ! keep pix cum : ) thank !',
#  'that cool ! sometim slow gentl . sonetim rough hard : )',
#  'ranjith cal drpd deeraj deepak 5min hold',
#  'review keep fantast nokia n-gage game deck club nokia , go 2 www.cnupdates.com/newslett . unsubscrib alert repli word',
#  'got outta class gon na go gym .',
#  'come friday leav pongal ? get news work place .',
#  "hi dear call urgnt . n't know what problem . n't want work problem least tell . wate repli .",
#  "friend got say 's up order gram ( 's got $ & lt ; # & gt ; ) , get ?",
#  'telli ? brdget jone !',
#  'yes .. saw messag ..',
#  '1 new voicemail . pleas call 08719181513 .',
#  'yesterday true true .',
#  "\\think u ; ) x\\ '' ''",
#  'made day . great day .',
#  'ok. c u .',
#  "n't b floppi ... b snappi & happi ! gay chat servic photo upload call 08718730666 ( 10p/min ) . 2 stop text call 08712460324",
#  'thing r good thanx got exam march ive done revis ? fran still boyf ? ive got ta interviw 4 exet bit worri ! x',
#  'big brother alert ! comput select u 10k cash # 150 voucher . call 09064018838 . ntt po box cro1327 18+ bt landlin cost 150ppm mobil vari',
#  "tell coulda real valentin n't ? u never pick noth ! !",
#  'gent ! tri contact . last weekend draw show å£1000 prize guarante . call 09064012160 . claim code k52 . valid 12hrs . 150ppm',
#  "u sure u ca n't take sick time ?",
#  'sorri uncl . i.ll keep touch',
#  'creep ? ; _ ;',
#  ': ) kalli home ground.amla home town durban : )',
#  'jus finish lunch way home lor ... tot u dun wan 2 stay sch today ...',
#  'rofl . true name',
#  'buzz ! hey , love ! think hope day goe well . sleep ? miss babe . long moment togeth * love smile *',
#  'one day train : - )',
#  'tell shola pleas go colleg medicin visit academ depart , tell academ secretari current situat ask transfer . ask someon check sagamu thing lautech . vital complet medic educ nigeria . less expens much less expens . unless get citizen rate new zealand .',
#  "n't heard anyth 's answer text 'm guess flake . said jb fantast",
#  "edison right said , \\a fool ask question wise man answer\\ '' know us speechless viva .. gm",
#  'project w fren lor .',
#  'captain room : )',
#  'valu custom , pleas advis follow recent review mob . award å£1500 bonus prize , call 09066364589',
#  'eeri nokia tone 4u , rpli tone titl 8007 eg tone dracula 8007 titl : ghost , addamsfa , munster , exorcist , twilight www.getzed.co.uk pobox36504w45wq 150p',
#  'good hear',
#  "ll probabl tomorrow ( even later tonight someth 's go )",
#  'ok thanx ...',
#  'ya ok , vikki vl c witin & lt ; # & gt ; min il repli u ..',
#  'ok .',
#  'hi da : ) today class ?',
#  'meet lunch la ...',
#  'ok set let u noe e detail later ...',
#  'ok ok take care . understand .',
#  'pls dont play other life .',
#  "n't eaten day . 'm sit stare juici pizza ca n't eat . med ruin life .",
#  "yeah , 's think",
#  'haha , thinkin',
#  "hi yiju ... 's regard 3230 textbook 's intro algorithm second edit ... 'm sell $ 50 ...",
#  'sir , wait call .',
#  'happi new year u !',
#  "hey , look like wrong one kappa guy number still phone , want text see 's around",
#  'mmmmm ... sooooo good wake word morn , love ! ! mmmm fuck ... love , lion ... * devour kiss across sea *',
#  'da . . vijay go talk jaya tv',
#  'slave ! want take 2 3 pictur today bright light cell phone ! bright light !',
#  'tell friend plan valentin day @ & lt ; url & gt ;',
#  'fanci shag ? do.interest ? sextextuk.com txt xxuk suzi 69876 . txts cost 1.50 per msg . tncs websit . x',
#  'sms servic . inclus text credit , pls goto www.comuk.net login= * * * * * unsubscrib stop . extra charg . help:08700469649 . po box420 . ip4 5we',
#  'eh sorri leh ... din c ur msg . sad alreadi lar . watch tv . u still offic ?',
#  'urgent pleas call 09066612661 landlin . å£5000 cash luxuri 4 * canari island holiday await collect . & cs sae award . 20m12aq . 150ppm . 16+ \x89ûï',
#  'gud mrng dear hav nice day',
#  'dear . ok ?',
#  'house-maid murder , coz man murder & lt ; # & gt ; th januari .. public holiday govt.instituit close , includ post offic .. understand ?',
#  'dont know support ass srt thnk . think ps3 play usb',
#  'yeah sure ll leav min',
#  'hey ... dont go watch x men lunch ... haha',
#  'go good ... problem .. still need littl experi understand american custom voic ...',
#  'yes : ) complet form : ) clark also utter wast .',
#  'oh realli ? perform , write paper , go movi home midnight , huh ?',
#  'sorri , ll call later',
#  'oh fine , ll tonight',
#  "'s ur paper ?",
#  'ur tonex subscript renew charg å£4.50 . choos 10 poli month . www.clubzed.co.uk * bill msg *',
#  "5p 4 alfi moon 's children need song ur mob . tell ur m8s . txt tone chariti 8007 nokia poli chariti poli : zed 08701417012 profit 2 chariti .",
#  'k .. k : ) ? perform ?',
#  "yes : ) last week 'm take live call .",
#  'final chanc ! claim ur å£150 worth discount voucher today ! text yes 85023 ! savamob , member offer mobil ! cs savamob pobox84 , m263uz . å£3.00 sub 16',
#  'themob > yo yo yo-her come new select hot download member get free ! click & open next link sent ur fone ...',
#  'guess could good excus , lol .',
#  'smile pleasur smile pain smile troubl pour like rain smile sum1 hurt u smile becoz someon still love see u smile ! !',
#  "'m realli realli broke oh . amount small even & lt ; # & gt ;",
#  'ah , well confus thing , doesn\x89û÷t ?',
#  'aight , sound good . want come ?',
#  'dun need use dial juz open da browser n surf ...',
#  'send id password',
#  'k k : ) sms chat .',
#  'way offic da ..',
#  '2 sleep bag , 1 blanket paper phone detail . anyth els ?',
#  'free > rington ! repli real poli eg real1 1 . pushbutton 2 . dontcha 3 . babygoodby 4 . golddigg 5 . webeburnin 1st tone free 6 u join å£3/wk',
#  'free ? call ?',
#  're final readi fyi',
#  'oki scare u say fat ... u dun wan alreadi ...',
#  'freemsg : fanci flirt ? repli date & join uk fastest grow mobil date servic . msgs rcvd 25p optout txt stop 83021 . repli date !',
#  'especi sinc talk boston person statement , lol ! woulda chang realiz said nyc ! say boston .',
#  'well . im computerless . time make oreo truffl',
#  'discuss mother ah ?',
#  'sorri chikku , cell got problem thts nt abl repli u msg u ..',
#  'congratul ! thank good friend u å£2,000 xmas prize . 2 claim easi , call 08718726971 ! 10p per minut . bt-national-r .',
#  'sunshin hol . claim ur med holiday send stamp self address envelop drink us uk , po box 113 , bray , wicklow , eir . quiz start saturday ! unsub stop',
#  'yes know cheesi song frosti snowman : )',
#  ": - ( 's v romant !",
#  'come n pick ì_ ... come immedi aft ur lesson ...',
#  'sorri complet forgot * pop em round week still ?',
#  "solv case : man found murder & lt ; decim & gt ; . & lt ; # & gt ; afternoon . 1 , wife call polic . 2 , polic question everyon . 3 , wife : sir , sleep , murder took place . 4.cook : cook . 5.garden : pick veget . 6.house-maid : went 2 post offic . 7.children : went 2 play . 8.neighbour : went 2 marriag . polic arrest murder immedi . 's ? repli reason , u r brilliant .",
#  'ìï predict wat time ì_ ll finish buy ?',
#  'dear 0776xxxxxxx u ve invit xchat . final attempt contact u ! txt chat 86688 150p/msgrcvdhg/suite342/2lands/row/w1j6hl ldn 18yr',
#  "tonight ? yeah , 'd",
#  'thank rington order , ref number k718 . mobil charg å£4.50 . tone arriv pleas call custom servic 09065069120',
#  'langport ? sorri , ll probabl bed 9pm . suck ill xmas ! go2sri lanka ?',
#  'camera - award sipix digit camera ! call 09061221066 fromm landlin . deliveri within 28 day .',
#  'sorri miss call . pleas call back .',
#  'u come back 4 dinner rite ? dad ask confirm wif u ...',
#  'work right ?',
#  'u want xmas ? 100 free text messag & new video phone half price line rental ? call free 0800 0721072 find !',
#  "sorri miss call let 's talk time . 'm 07090201529",
#  'easi ah ? sen got select mean good ..',
#  'yes obvious , eggs-pert potato head\x89û_ speak soon !',
#  'ha ... u jus ate honey ar ? sweet ...',
#  'congratul ur award 500 cd voucher 125gift guarante & free entri 2 100 wkli draw txt music 87066 tncs www.ldew.com1win150ppmx3age16',
#  "free entri 2 wkli comp win fa cup final tkts 21st may 2005 . text fa 87121 receiv entri question ( std txt rate ) & c 's appli 08452810075over18 's",
#  "lol ... realli need rememb eat 'm drink appreci keep compani night babe * smile *",
#  'want new video phone ? 600 anytim network min 400 inclus video call download 5 per week free deltomorrow call 08002888812 repli',
#  'go walmart . i.ll stay .',
#  "idk . keep say re , sinc move , keep but head freedom vs. respons . 'm tire . much shit deal 'm bare keep togeth get ad .",
#  'ok would b love , u r sure . think wot u want , drinkin , dancin , eatin , cinema , , , ... u ! wot ?',
#  'ok .',
#  'send text . ll skype later .',
#  'sorri , ll call later',
#  'arngd marriag u r walkin unfortunt snake bite u. bt love marriag danc frnt snake & amp ; sayin bite , bite .',
#  'yo come carlo soon',
#  'ur sis ?',
#  'prefer free day ... tue , wed , fri oso ... ìï ask workin lor ...',
#  'u dun drive go 2 sch .',
#  "n't know 'm rape dude poker",
#  "mmmm ... fuck ... fair ! know weak ! * grin * * push knee 's * * expos belli pull head * n't forget ... know * wick smile *",
#  "aight ve set free , think could text blake 's address ? occur 'm quit sure 'm thought",
#  'look addi goe back monday , suck',
#  'call germani 1 penc per minut ! call fix line via access number 0844 861 85 85 . prepay . direct access !',
#  "dont give monkey wot think certain n't mind . friend mine & ! n't sleep wiv , wud annoyin !",
#  'went ganesh dress shop',
#  'someon conact date servic enter phone fanci ! find call landlin 09111030116 . pobox12n146tf15',
#  'free msg : bill mobil number mistak shortcod 83332.pleas call 08081263000 charg refunded.thi call free bt landlin',
#  'hey angri . repli dr .',
#  "honey boo 'm miss u .",
#  'hey mr go sea view coupl gay mean game ! give bell ya finish',
#  'ya ! ì_ take ure practic lesson ? start june ..',
#  'oh ... kay ... sat right ?',
#  'hey ... time drive fri ? go evalu fri ?',
#  'u konw waht rael friendship im gving yuo exmpel : jsut ese tih msg .. evrey splle tih msg wrnog .. bt sitll yuo ra wihtuot ayn mitsak .. goodnight & amp ; nice sleep .. sweet dream ..',
#  "8007 25p 4 alfi moon 's children need song ur mob . tell ur m8s . txt tone chariti 8007 nokia poli chariti poli : zed 08701417012 profit 2 chariti",
#  'juz havent woke bit blur blur ... ? dad went liao ... cant cum oso ...',
#  'good night . go sleep .',
#  'sir , wait letter .',
#  "'s weather ?",
#  'time u get ?',
#  'ok ... din get ur msg ...',
#  "watch tv lor ... funni bluff 4 wat . izzit thk 's imposs us ?",
#  "sorri , batteri die , come 'm get gram , 's place ?",
#  "ur chanc win å£250 cash everi wk txt : action 80608 . 's & c 's www.movietrivia.tv custcar 08712405022 , 1x150p/wk .",
#  'long fuckin showr',
#  "well 'm desper ll call armand",
#  'dear u ve invit xchat . final attempt contact u ! txt chat 86688 150p/msgrcvdhg/suite342/2lands/row/w1j6hl ldn 18 yrs',
#  'k : ) k : ) detail want transfer ? acc enough ?',
#  'cant pick phone right . pls send messag',
#  'prob hon ! u doinat mo ?',
#  "anyway n't think secur anyth , lem know want drive south chill",
#  'oh gei . happend tron . mayb ill dl 3d',
#  'issu right . ill fix tomorrow .',
#  'date sunday ! !',
#  'thank 4 continu support question week enter u in2 draw 4 å£100 cash . name new us presid ? txt an 80082',
#  'aight text re back mu ll swing , need somebodi get door',
#  'cant wait see ! photo use ? : )',
#  'kothi print marandratha .',
#  'effect irrit . ignor',
#  'kalli wont bat 2nd inning .',
#  'rington club : gr8 new poli direct mobil everi week !',
#  'ha ha cool cool chikku chikku : - ) : -db- )',
#  "sir . 's 8-hr trip bus last week . anoth audit next wednesday think might drive time .",
#  'r ì_ go send ?',
#  'oki',
#  'call freephon 0800 542 0578 !',
#  'left vagu . said would inform person account delay rent discuss hous agenc rent anoth place . check onlin place around usc & lt ; # & gt ;',
#  "mmmmmm ... love , much , ahmad ... ca n't wait year begin everi second take closer side . happi new year , love ! !",
#  "sad stori man - last week b'day . wife did'nt wish . parent forgot n kid . went work . even colleagu wish . enter cabin pa said , `` happi b'day boss ! ! '' . felt special . askd 4 lunch . lunch invit apart . went . said , '' u mind go bedroom minut ? `` '' ok '' , sed sexi mood . came 5 minut latr wid cake ... n wife , parent , kidz , friend n colleagu . scream .. surpris ! ! wait sofa .. ... ..... ' nake ... !",
#  'plan famili set stone ?',
#  'okay lor ... still let us go ah ? coz know later . drop card box right ?',
#  "nope 'm go home go pump petrol lor ... like go 2 rain soon ...",
#  'help propos go back tomorrow',
#  'hi jon , pete , ive bin 2 spain recent & hav sum dinero left , bill said u ur åôrent mayb interest , hav 12,000pes , around å£48 , tb , jame .',
#  'congrat ! 1 year special cinema pass 2 . call 09061209465 ! c suprman v , matrix3 , starwars3 , etc 4 free ! bx420-ip4-5w . 150pm . dont miss !',
#  'fuuuuck need stop sleepin , sup',
#  'well that nice . bad cant eat',
#  'way , make sure u get train worc foreg street shrub hill . fun night x',
#  'thank . tesco quit nice . gone . speak soon',
#  'å£1000 winner guarante caller prize , final attempt contact ! claim call 09071517866 ! 150ppmpobox10183bhamb64x',
#  "storm msg : wen u lift phne , u say \\hello\\ '' u knw wt real mean hello ? ? . . . 's name girl .. ! . . . yes .. u knw dat girl ? ? \\ '' margaret hello\\ '' girlfrnd f grahmbel invnt telphon ... . . . . moral : one 4get name person",
#  "sorri man account 's dri would , want could trade back half could buy shit credit card",
#  'ok lor go tog lor ...',
#  'sorri , guess whenev get hold connect , mayb hour two ? ll text',
#  'panason & bluetoothhdset free . nokia free . motorola free & doublemin & doubletxt orang contract . call mobileupd8 08000839402 call 2optout',
#  "aah ! cuddl would lush ! 'd need lot tea soup kind fumbl !",
#  'pleas reserv ticket saturday eve chennai thirunelvali tirunelvali chennai sunday eve ... alreadi see net .. ticket avail .. want book ticket tackl ..',
#  "'m meet darren ...",
#  'one teach ship car .',
#  'okey dokey swashbuckl stuff oh .',
#  '\\si.como ? ! listened2th plaid album-quit gd & new air1 hilarious-also boughtåóbraindanceåóa comp.ofstuff aphexåõ ; abel',
#  'danc river ?',
#  'spjanuari male sale ! hot gay chat cheaper , call 08709222922 . nation rate 1.5p/min cheap 7.8p/min peak ! stop text call 08712460324 ( 10p/min )',
#  'mayb westshor hyde park villag , place near hous ?',
#  'wonder ... cos dun rem see silver car ... thk saw black one ...',
#  'im gonnamissu much ! ! would say il send u postcard butther abouta much chanc merememberin asther ofsi breakin contract ! ! luv yaxx',
#  "forc eat slice . 'm realli hungri tho . suck . mark get worri . know 'm sick turn pizza . lol",
#  'ur face test ( 1 2 3 4 5 6 7 8 9 & lt ; # & gt ; ) select number tell ur face astrolog .... wait . quick repli ...',
#  '. guess got screwd',
#  'teach app da . come colleg .',
#  'long take get .',
#  "'m good movi , ok leav hourish ?",
#  'feel like tri kadeem ? : v',
#  'u ...',
#  'cheer lou ! yeah goodnit shame u neva came ! c ya gailxx',
#  'realli need 2 kiss u miss u babi ur babi 4eva',
#  'u subscrib best mobil content servic uk å£3 per ten day send stop 83435 . helplin 08706091795 .',
#  'hi 07734396839 ibh custom loyalti offer : new nokia6600 mobil å£10 txtauction ! txt word : start no:81151 & get ! 4t &',
#  'hi.what think match ?',
#  'yeah imma come caus jay want drug',
#  'book ticket pongal ?',
#  'get 3 lion england tone , repli lionm 4 mono lionp 4 poli . 4 go 2 www.ringtones.co.uk , origin n best . tone 3gbp network oper rate appli .',
#  'mean fat head',
#  "final happen .. ! aftr decad .. ! beer cheaper petrol ! gover expect us \\drink\\ '' . . . n't \\ '' drive \\ '' ''",
#  'ok go sleep . hope meet .',
#  'food',
#  'hey what ? u sleep morn ?',
#  'otherwis part time job na-tuit ..',
#  "today 'm workin free oso ... gee ... thgt u workin ur fren 's shop ?",
#  'eh ur laptop got stock lei ... say mon muz come take look c got ...',
#  'hey ! glad u r better . hear u treat urself digi cam , good ? r 9pm . fab new year , c u coupla wks !',
#  'ok ... said ve got wisdom teeth hidden insid n mayb need 2 remov .',
#  'jordan got vote last nite !',
#  'black shirt n blue jean ... thk c ì_ ...',
#  'wish u mani mani return day .. happi birthday vikki ..',
#  'cos want thing',
#  'contact date servic someon know ! find , call land line 09050000878 . pobox45w2tg150p',
#  'saw message.it k da : )',
#  "'m leav hous ...",
#  'great ! shoot big load get readi !',
#  '? hope ve settl new school year . wishin gr8 day',
#  "\\happi valentin day\\ '' know earli hundr handsom beauti wish . thought finish aunti uncl 1st ... ''",
#  'ya nice . . .be readi thursday',
#  'g want know fuck',
#  'hahaha .. use brain dear',
#  'someon u know ask date servic 2 contact ! cant guess ? call 09058091854 reveal . po box385 m6 6wu',
#  'well done england ! get offici poli rington colour flag yer mobil ! text tone flag 84199 ! opt-out txt eng stop . box39822 w111wx å£1.50',
#  'urgent ! pleas call 09061213237 landlin . å£5000 cash luxuri 4 * canari island holiday await collect . & cs sae po box 177 . m227xi . 150ppm . 16+',
#  "told hr want post chennai : ) 'm work : )",
#  "'m alway look excus citi .",
#  'hi . : ) technic support.provid assist us custom call email : )',
#  'time come tomorrow',
#  'k.k : ) apo k.good movi .',
#  'make babi yo tho',
#  "yup 'm still coffe wif fren ... fren drove ll give lift ...",
#  'die ... e toot fring ...',
#  'make sure alex know birthday fifteen minut far re concern',
#  'yo , jp hungri like mofo ?',
#  'lmao ! nice 1',
#  'twenti past five said train durham alreadi coz reserv seat',
#  'thank babi ! cant wait tast real thing ...',
#  've sent wife text . buy ll tell . relax . go get wkend .',
#  'oki',
#  'xmas & new year eve ticket sale club , day 10am till 8pm , thur , fri & sat night week . re sell fast !',
#  'okay ... book alreadi ... includ one bugi .',
#  'mark work tomorrow . get 5 . work hous meet u afterward .',
#  'went pay rent . go bank authoris payment .',
#  'wat happen cruis thing',
#  'didnt holla ?',
#  'way transport less problemat sat night . way , u want ask n join bday , feel free . need know definit nos book fri .',
#  'stupid.it possibl',
#  'k tell anyth .',
#  "say 's quit least5tim day wud n't take much notic . nah , n't mind . gon na see ? want come taunton tonight ? u tell !",
#  'new year plan ?',
#  'alway chat . fact need money rais ?',
#  'uncl atlanta . wish guy great semest .',
#  "'s adult would learn experi . 's real danger . dont like peep use drug dont need . comment",
#  'duck chinchilla',
#  'get cash togeth ll text jason',
#  'men like shorter ladi . gaze eye .',
#  "'s still work . time also tri ad zero . save . check & lt ; # & gt ;",
#  "well , 'm gon na finish bath . good ... fine night .",
#  'thanx lot 4 ur help !',
#  'yun ah.now ì_ wkg ? btw ì_ go nus sc . ìï wana specialis wad ?',
#  "ca n't describ lucki 'm actual awak noon",
#  'urgent ! mobil * * * * * * * * * * * å£2,000 bonus caller prize 02/06/03 ! 2nd attempt reach ! call 09066362220 asap ! box97n7qp , 150ppm',
#  'much dirti fellow ?',
#  'ì_ come n pick 530 ar ?',
#  'natalja ( 25/f ) invit friend . repli yes-440 no-440 see : www.sms.ac/u/nat27081980 stop ? send stop frnd 62468',
#  "wow . re right ! n't mean . guess gave boston men chang search locat nyc , someth chang . cuz signin page still say boston .",
#  'poke man everyday teach canada abi ! . say hi .',
#  'beauti truth : express face could seen everyon ... depress heart could understood love one .. gud ni8 ; - )',
#  'import custom servic announc premier . call freephon 0800 542 0578 !',
#  'heart empti without love .. mind empti without wisdom .. eye r empti without dream & amp ; life empti without frnds .. alwi touch . good night & amp ; sweet dream',
#  'lol wtf random . btw lunch break',
#  'anyth valuabl 2 situat : first- get ... second- loos ...',
#  'hellogorg , how u ? fone charg lst nitw wen u texd . hopeu ad nice wkend im sure u lookin 4ward 2 c-in u 2mrw luv jaz',
#  'dear good morn',
#  'hai ana tomarrow come morn . & lt ; decim & gt ; ill sathi go rto offic . repli came home .',
#  'ok come ur home half hour',
#  'kaiez ... enjoy ur tuition ... gee ... thk e second option sound beta ... ll go yan jiu den msg u ...',
#  'thank chikku .. : - ) gud nyt : - *',
#  'headin toward busetop',
#  'sir , need axi bank account bank address .',
#  'www.applausestore.com monthlysubscript @ 50p/msg max6/month & csc web age16 2stop txt stop',
#  "singl line big mean : : : : : \\miss anyth 4 ur \\ '' best life\\ ''",
#  "'m still pretti weak today .. bad day ?",
#  'phoni å£350 award - today voda number end xxxx select receiv å£350 award . match pleas call 08712300220 quot claim code 3100 standard rate app',
#  "'m class . get text .",
#  "n't seen facebook , huh ? lol !",
#  'thanx4 today cer nice 2 catch ave 2 find time often oh well take care c u soon.c',
#  'yes . rent expens way save .',
#  "oh god ! ve found number ! 'm glad , text back xafter msgs cst std ntwk chg å£1.50",
#  'saw guy doll last night patrick swayz great',
#  've got & lt ; # & gt ; , way could pick ?',
#  'k. sent',
#  'happen adventur',
#  'daddi bb .',
#  'oh ok didnt know meant . yep babi jontin',
#  'u noe 2 send file 2 comput ?',
#  'sian ... aft meet supervisor got work 2 liao ... u work ?',
#  'go wipro interview today ?',
#  'pleas ask mummi call father',
#  'oh , yes , ve littl weather ve kind coccoon home',
#  'beliv . come home .',
#  'readi * big day tomorrow ?',
#  'doubl min & txts orang 1/2 price linerent - motorola sonyericsson b/tooth free-nokia free call mobileupd8 08000839402 or2optout/hv9d',
#  "free entri 2 week comp chanc win ipod . txt pod 80182 get entri ( std txt rate ) & c 's appli 08452810073 detail 18+",
#  '18 day euro2004 kickoff ! u kept inform latest news result daili . unsubscrib send get euro stop 83222 .',
#  "fuck babe ... miss alreadi , know ? ca n't let send money toward net ? need ... want ... crave ...",
#  'mmmmmmm * snuggl * ... * deep content sigh * ... * whisper * ... fuck love much bare stand ...',
#  '.. ful song lyric ..',
#  '( career tel ) ad u contact indyarocks.com send free sms . remov phonebook - sms & lt ; # & gt ;',
#  'told come wednesday .',
#  '3 free tarot text ! find love life ! tri 3 free ! text chanc 85555 16 ! 3 free , msgs å£1.50',
#  ', dont know oh',
#  'plan manag',
#  'mani time lose best one bcoz',
#  'u studi sch go home ? anyway ll b go 2 sch later .',
#  'excel thought misundrstud frnd : knw u hate bt day wen u ll knw truth u ll hate urself : - ( gn : - )',
#  'thank calling.forgot say happi onam sirji.i fine rememb met insur person.meet qatar insha allah.rakhesh , ex tata aig join tissco , tayseer .',
#  "aww 's first time u said u miss without ask miss u first . love ! : )",
#  'posibl dnt live & lt ; # & gt ; centuri cm frwd n thnk differ',
#  'yes mani sweet',
#  'got hella gas money , want go grand natur adventur galileo littl bit ?',
#  'omg make wed chapel frontiervill ? get good stuff ?',
#  'happi new year melodi !',
#  'join today formally.pl keep praying.wil talk later .',
#  'call .. messag .. miss call',
#  'u noe wat time e place dat sell 4d close ?',
#  "'s realli skateboard despit fact get thrown wind bandag shit arm everi five minut",
#  '87077 : kick new season 2wks free goal & news ur mobil ! txt ur club name 87077 eg villa 87077',
#  "pathaya enketa maraikara pa '",
#  'need lar go engin ? cos sis art today ...',
#  'ok ...',
#  '* think chuckin ur red green n black trainner 2 save carryin bac train',
#  'yup ve finish c ì_ ...',
#  'collect ur laptop ?',
#  'good afternoon sexi bun ! goe job search ? wake first thought alway , love . wish fine happi know ador !',
#  'said matter . mind say matter .',
#  'parti alex nichol',
#  'dear got & lt ; # & gt ; dollar hi hi',
#  "take n't phone callon friday . assum wo n't year ?",
#  'princess , kitti shave natur ?',
#  "ca n't take major role communiti outreach . rock mel",
#  'urgent ! tri contact u today draw show å£800 prize guarante . call 09050000460 land line . claim j89 . po box245c2150pm',
#  'dunno , dad said come home 2 bring us 4 lunch . yup go w u lor . call u reach school lor ...',
#  'ok ...',
#  'case guess ll see campus lodg',
#  'cool , text re park',
#  'prob . send email .',
#  'hmm ill think ... ok re forgiven ! =d',
#  "'m use . hope agent n't drop sinc ve book thing year . whole boston , nyc experi .",
#  "wait 's still clear , sure sarcast 's x n't want live us",
#  'good morn princess ! ?',
#  'fps .',
#  "comput fri essenti part n't keep spare fuck idiot roommat looovvv leav thing run full & lt ; # & gt ; /7",
#  'ok c ì_ .',
#  'realli dun bluff leh ... u sleep earli . nite ...',
#  'custom servic announc . recent tri make deliveri unabl , pleas call 07099833605 re-schedul . ref:9280114',
#  'sent jd custom servic cum account execut ur mail id , detail contact us',
#  'hope great day .',
#  "n't worri , * easi ingredi !",
#  'oki ...',
#  'check wid corect spele i.e . sarcasm',
#  'ya tel , wat ur problem ..',
#  "school start . stay . 's weather like . food . social support system like friend school . thing import .",
#  'may call later pls',
#  "fwiw reason 'm around 's time smoke gas afford around someon tell appar happen somebodi want light",
#  'custom place , wil cal u sir .',
#  'hey hun-onbus goin 2 meet . want 2go 4a meal donyt feel like cuz 2 get last bus home ! hes sweet latelyxxx',
#  "ca n't . feel nauseous . 'm piss . n't eat sweet week caus today plan pig . diet week . 'm hungri : /",
#  'free today haf 2 pick parent tonit ...',
#  'pain words- \\i thought happi toughest thing earth ...',
#  'know account detail .. ask mom send you.mi mom reach .',
#  'hi happi birthday . hi hi hi hi hi hi hi',
#  'come tomorrow di',
#  'sound like mani talent ! would like go dinner date next week ?',
#  'yo im right yo work',
#  'home watch tv lor .',
#  'aiyo bit pai seh ì_ noe ... scare dun rem die ... hee ... becom better lookin oredi leh ...',
#  'mum , hope great day . hope text meet well full life . great day . abiola',
#  'k.k.this month kote birthday know ?',
#  'want sent & lt ; # & gt ; mesag today . that . sorri hurt',
#  '; - ) ok . feel like john lennon .',
#  'yeah prob - last night obvious catch ... speak soon',
#  'sir , wait call , free pleas call .',
#  "sorri , ca n't help .",
#  'yar ... tot u knew dis would happen long ago alreadi .',
#  'meet da . call',
#  "lost 4 pound sinc doc visit last week woot woot ! 'm gon na celebr stuf face !",
#  'shall come get pickl',
#  'open rebtel firefox . load put plus sign user name place , show two number . lower number number . pick number pin display okay !',
#  'good afternoon , love . goe day ? ? woke earli onlin wait ... hmmm ... italian boy onlin see . * grin *',
#  'respond',
#  "ok lor . 'm town lei .",
#  'ok cool . see ya .',
#  'hai priya right . doctor said pa. .',
#  'yup song bro . creativ . neva test qualiti . said check review onlin .',
#  '. call meet',
#  "n't forget own 's privat properti ... good boy alway .. * passion kiss *",
#  'packag program well',
#  'hmmm.still dont open ?',
#  "'m chennai velacheri : )",
#  "sound like plan ! cardiff still still cold ! 'm sit radiat !",
#  'unbeliev faglord',
#  'oh k.k .. take test ?',
#  'i\x89û÷ll leav around four , ok ?',
#  'also bring galileo dobbi',
#  "ha ha nan yalrigu heltini .. iyo kothi chikku , u share mani thing wit .. far n't told bodi even utter word abt u .. ur trust much tell other .. plz nxt time dont use word .. ok , chikku : - ) ; - ) b- )",
#  "'m workin . get job ...",
#  'suck . ll go u hair . ll free right ?',
#  'see half hour',
#  '26th juli',
#  'dear , take care . reach home.lov u lot .',
#  'u guy never invit anywher : (',
#  'uniqu user id 1172 . remov send stop 87239 custom servic 08708034412',
#  'yo guy ever figur much need alcohol ? jay tri figur much safe spend weed',
#  'block breaker come delux format new featur great graphic t-mobil . buy å£5 repli get bbdelux take challeng',
#  'see requir pleas',
#  '! 4 * costa del sol holiday å£5000 await collect . call 09050090044 toclaim . sae , tc , pobox334 , stockport , sk38xh , costå£1.50/pm , max10min',
#  ...]

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression(class_weight='balanced')

# %%
model.score(X_test, y_test)
# Out:
# 0.97847533632287

# %%
model.predict(X_test[4])
# Out:
# array([1])

# %%
y_test
# Out:
# 3245    0
# 944     0
# 1044    1
# 2484    0
# 812     1
#        ..
# 4264    0
# 2439    0
# 5556    0
# 4205    0
# 4293    1
# Name: target, Length: 1115, dtype: int64

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, confusion_matrix, classification_report

# Assuming y_test is the true labels and y_pred are the predicted labels
y_pred = model.predict(X_test)
y_prob = model.predict_proba(X_test)[:, 1]  # for AUC and Log-Loss

# Metrics
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
roc_auc = roc_auc_score(y_test, y_prob)
cm = confusion_matrix(y_test, y_pred)

# Classification Report (provides precision, recall, F1, support for each class)
report = classification_report(y_test, y_pred)

# Print the results
print(f"Accuracy: {accuracy}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F1 Score: {f1}")
print(f"AUC: {roc_auc}")
print("Confusion Matrix:")
print(cm)
print("Classification Report:")
print(report)
# Out:
# Accuracy: 0.97847533632287
# Precision: 0.92
# Recall: 0.92
# F1 Score: 0.92
# AUC: 0.9889464594127807
# Confusion Matrix:
# [[953  12]
#  [ 12 138]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       965
#            1       0.92      0.92      0.92       150
#
#     accuracy                           0.98      1115
#    macro avg       0.95      0.95      0.95      1115
# weighted avg       0.98      0.98      0.98      1115

# %% [markdown]
# #**Now model is created for spam classifocation , let's again create the model for converting users message to vector format and classifying whether it's spam or ham**

# %%
def tokenizatio(text):
    return word_tokenize(text)
def stem_text(text):
    stemmer = SnowballStemmer("english")
    stop_words = set(stopwords.words('english'))

    return [stemmer.stem(word) for word in text if word.lower() not in stop_words]

# Initialize the TfidfVectorizer with the vocabulary from training


message = input("Enter any message:")
message = tokenizatio(message)
message = stem_text(message)
message = ' '.join(message)  # Join tokens into a string for TF-IDF
message_vector = vectorizer.transform([message])  # Transform using TF-IDF

# Make prediction using the TF-IDF vector
prediction = model.predict(message_vector)
print(prediction)
print("Spam" if prediction[0]==1 else "ham")
# Out:
# Enter any message:Congratulations! You've won a free iPhone. Click here to claim your prize.
# [1]
# Spam
